# %%
import pandas as pd

# %%
df= pd.read_csv("dailyActivity_merged.csv")
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
df.isna().sum()
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
df.shape
# Out:
# (457, 15)

# %%
df.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  4.570000e+02    457.000000     457.000000       457.000000
# mean   4.628595e+09   6546.562363       4.663523         4.609847
# std    2.293781e+09   5398.493064       4.082072         4.068540
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.347168e+09   1988.000000       1.410000         1.280000
# 50%    4.057193e+09   5986.000000       4.090000         4.090000
# 75%    6.391747e+09  10198.000000       7.160000         7.110000
# max    8.877689e+09  28497.000000      27.530001        27.530001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                457.000000          457.000000                457.000000
# mean                   0.179427            1.180897                  0.478643
# std                    0.849232            2.487159                  0.830995
# ...

# %%
zero_columns = df.columns[(df == 0).all()].tolist()

# %%
zero_columns
# Out:
# []

# %%
df.drop(columns=["LoggedActivitiesDistance", "SedentaryActiveDistance", "TrackerDistance"], inplace=True)

# %%
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  VeryActiveDistance  \
# 0  1503960366    3/25/2016       11004           7.11                2.57
# 1  1503960366    3/26/2016       17609          11.55                6.92
# 2  1503960366    3/27/2016       12736           8.53                4.66
# 3  1503960366    3/28/2016       13231           8.93                3.19
# 4  1503960366    3/29/2016       12041           7.85                2.16
#
#    ModeratelyActiveDistance  LightActiveDistance  VeryActiveMinutes  \
# 0                      0.46                 4.07                 33
# 1                      0.73                 3.91                 89
# 2                      0.16                 3.71                 56
# 3                      0.79                 4.95                 39
# 4                      1.09                 4.61                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# ...

# %%
df.drop(columns=["Id","ActivityDate"], inplace=True)

# %%
df.head()
# Out:
#    TotalSteps  TotalDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0       11004           7.11                2.57                      0.46
# 1       17609          11.55                6.92                      0.73
# 2       12736           8.53                4.66                      0.16
# 3       13231           8.93                3.19                      0.79
# 4       12041           7.85                2.16                      1.09
#
#    LightActiveDistance  VeryActiveMinutes  FairlyActiveMinutes  \
# 0                 4.07                 33                   12
# 1                 3.91                 89                   17
# 2                 3.71                 56                    5
# 3                 4.95                 39                   20
# 4                 4.61                 28                   28
#
#    LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   205               804      1819
# ...

# %%
df.to_csv("reformed_data.csv", index=False)
